# %% [markdown]
# <a href="https://colab.research.google.com/github/Bugsbugme/stable-diffusion-hello-world/blob/main/StableDiffusion_HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Nov 21 06:27:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install diffusers
# !pip install transformers scipy ftfy
# !pip install "ipywidgets>=7,<8"
# !pip install accelerate

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
import torch
from diffusers import StableDiffusionPipeline

# make sure you're logged in with `huggingface-cli login`
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16)

# %%
pipe = pipe.to("cuda")

# %%
prompt = "a photograph of an astronaut riding a horse"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FB8FC92E450>
